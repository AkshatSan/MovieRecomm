# %% [markdown]
# # Movie recommendation

# %% [markdown]
# # Dataset-
# the data set used here is very famous movielens 1m dataset

# %%
#importing useful libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
base_path = '..' #/Users/akshatpandey/Thesisproject/Movie recommendation/data/ratings.csv

# %%
# Reading ratings file
# Ignore the timestamp column
#sep and encoding is used because csv file is not in correct format


ratings = pd.read_csv(base_path+'//data//ratings.csv',sep='\t', encoding='latin-1',usecols=['user_id', 'movie_id', 'rating'])

# Reading users file
users = pd.read_csv(base_path+'//data//users.csv',sep='\t' ,encoding='latin-1',usecols=['user_id', 'gender', 'zipcode', 'age_desc', 'occ_desc'])

# Reading movies file
movies = pd.read_csv(base_path+'//data//movies.csv',sep='\t',encoding='latin-1', usecols=['movie_id', 'title', 'genres'])

# %%
max_userid = ratings['user_id'].drop_duplicates().nunique()
max_movieid = ratings['movie_id'].drop_duplicates().nunique()
# Out:
# 6040
# 3952

# %%
#unique user and movie ids
print (max_userid)
print(max_movieid)
# Out:
# 6040
# 3952

# %%
ratings.head(5)
# Out:
#    user_id  movie_id  rating
# 0        1      1193       5
# 1        1       661       3
# 2        1       914       3
# 3        1      3408       4
# 4        1      2355       5

# %%
users.head(5)
# Out:
#    user_id gender zipcode  age_desc              occ_desc
# 0        1      F   48067  Under 18          K-12 student
# 1        2      M   70072       56+         self-employed
# 2        3      M   55117     25-34             scientist
# 3        4      M   02460     45-49  executive/managerial
# 4        5      M   55455     25-34                writer

# %%
movies.head(5)
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 3 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   user_id   1000209 non-null  int64
#  1   movie_id  1000209 non-null  int64
#  2   rating    1000209 non-null  int64
# dtypes: int64(3)
# memory usage: 22.9 MB

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6040 entries, 0 to 6039
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   6040 non-null   int64
#  1   gender    6040 non-null   object
#  2   zipcode   6040 non-null   object
#  3   age_desc  6040 non-null   object
#  4   occ_desc  6040 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 236.1+ KB

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  3883 non-null   int64
#  1   title     3883 non-null   object
#  2   genres    3883 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 91.1+ KB

# %% [markdown]
# # WordCloud

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.2.tar.gz (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 197.1 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.6.1 in /Users/akshatpandey/Thesisproject/env/lib/python3.8/site-packages (from wordcloud) (1.22.3)
# Requirement already satisfied: pillow in /Users/akshatpandey/Thesisproject/env/lib/python3.8/site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/akshatpandey/Thesisproject/env/lib/python3.8/site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/akshatpandey/Thesisproject/env/lib/python3.8/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/akshatpandey/Thesisproject/env/lib/python3.8/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/akshatpandey/Thesisproject/env/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/akshatpandey/Thesisproject/env/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in /Users/akshatpandey/Thesisproject/env/lib/python3.8/site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/akshatpandey/Thesisproject/env/lib/python3.8/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/akshatpandey/Thesisproject/env/lib/python3.8/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/akshatpandey/Thesisproject/env/lib/python3.8/site-packages (from matplotlib->wordcloud) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/akshatpandey/Thesisproject/env/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.15.0)
# Requirement already satisfied: six>=1.5 in /Users/akshatpandey/Thesisproject/env/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.15.0)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py) ... done
#   Created wheel for wordcloud: filename=wordcloud-1.9.2-cp38-cp38-macosx_11_0_arm64.whl size=155104 sha256=732f627f184abf22ce1f1eccf16bf95a4e2f5d83076b8cb9c69b27eec7687c24
#   Stored in directory: /Users/akshatpandey/Library/Caches/pip/wheels/91/ec/76/830440a234d211054cf724db3a3c30b66709ad1685ac9618fa
# Successfully built wordcloud
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2

# %%
# Import new libraries
# %matplotlib inline
import wordcloud
from wordcloud import WordCloud, STOPWORDS

# %%
# Create a wordcloud of the movie titles
#movies['title'] = movies['title'].fillna("").astype('str')
movies["title"] = movies["title"]
title_corpus = ' '.join(movies['title'])
title_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='blue', height=1000, width=2000).generate(title_corpus)

# Plot the wordcloud
plt.figure(figsize=(12,8))
plt.imshow(title_wordcloud)
plt.axis('off')
plt.show()

# %%
# Out:
# 0
